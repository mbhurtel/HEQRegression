# %% [markdown]
# # Data Preprocessing - After Class Update

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
import os
import json
# from pickle import dump
from google.colab import files

# %%
# !gdown --id 11n0QOY5LuFQBfZSYrwJuQWVtYohFMjoy
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=11n0QOY5LuFQBfZSYrwJuQWVtYohFMjoy
# To: /content/filtered_data.csv
# 100% 59.1M/59.1M [00:00<00:00, 162MB/s]

# %%
data = pd.read_csv("filtered_data.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (2) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.head()
# Out:
#       city state house      street  ... fireplace water  sewer  housePrice
# 0  Lilburn    GA   249  Rockbridge  ...   Masonry   Yes    NaN      179300
# 1  LILBURN    GA   NaN         NaN  ...   Masonry   Yes    NaN      210500
# 2  Lilburn    GA    63   Lancaster  ...   Masonry   Yes    NaN      251400
# 3  Lilburn    GA   218      Coteau  ...   Masonry   Yes    NaN      215400
# 4  Lilburn    GA   169       Coeur  ...   Masonry   Yes    NaN      191800
#
# [5 rows x 29 columns]

# %%
data.architecturalStyle.value_counts(dropna=False)
# Out:
# Conventional     178234
# NaN               83639
# Ranch/Rambler     19261
# Colonial           4876
# Cape Cod            606
# Modern              281
# Prefab               10
# Cottage               1
# Name: architecturalStyle, dtype: int64

# %%
data["architecturalStyle"] = data["architecturalStyle"].fillna("Others")

# %%
data.architecturalStyle.value_counts(dropna=False)
# Out:
# Conventional     178234
# Others            83639
# Ranch/Rambler     19261
# Colonial           4876
# Cape Cod            606
# Modern              281
# Prefab               10
# Cottage               1
# Name: architecturalStyle, dtype: int64

# %%
data.heating.value_counts(dropna=False)
# Out:
# Forced air    253950
# NaN            30976
# Yes             1870
# Central           82
# None              23
# Heat Pump          7
# Name: heating, dtype: int64

# %%
# Because we don't know what type of heating is "Yes"
data = data.drop(data[data["heating"] == "Yes"].index)

# %%
data["heating"] = data["heating"].fillna("Others")

# %%
data.heating.value_counts(dropna=False)
# Out:
# Forced air    253950
# Others         30976
# Central           82
# None              23
# Heat Pump          7
# Name: heating, dtype: int64

# %%
data.fireplace.value_counts(dropna=False)
# Out:
# Masonry    234330
# NaN         50708
# Name: fireplace, dtype: int64

# %%
data["fireplace"] = data["fireplace"].fillna("Others")

# %%
data.fireplace.value_counts(dropna=False)
# Out:
# Masonry    234330
# Others      50708
# Name: fireplace, dtype: int64

# %%
data.airConditioning.value_counts(dropna=False)
# Out:
# Yes        253853
# NaN         19851
# None        11333
# Partial         1
# Name: airConditioning, dtype: int64

# %%
data["airConditioning"] = data["airConditioning"]

# %%
data = data.drop(data[data["airConditioning"] == "Partial"].index)

# %%
data.airConditioning.value_counts(dropna=False)
# Out:
# Yes     253853
# NaN      19851
# None     11333
# Name: airConditioning, dtype: int64

# %%
data.foundation.unique()
# Out:
# array(['Crawl Space/Raised', nan], dtype=object)

# %%
data["foundation"] = data["foundation"].fillna("Others")

# %%
data.foundation.unique()
# Out:
# array(['Crawl Space/Raised', 'Others'], dtype=object)

# %%
housePrice = data["housePrice"]
data.drop(columns="housePrice", inplace=True)

# %%
data["soldYear"] = 2021

# %%
data.head()
# Out:
#       city state house      street  ... fireplace water  sewer  soldYear
# 0  Lilburn    GA   249  Rockbridge  ...   Masonry   Yes    NaN      2021
# 1  LILBURN    GA   NaN         NaN  ...   Masonry   Yes    NaN      2021
# 2  Lilburn    GA    63   Lancaster  ...   Masonry   Yes    NaN      2021
# 3  Lilburn    GA   218      Coteau  ...   Masonry   Yes    NaN      2021
# 4  Lilburn    GA   169       Coeur  ...   Masonry   Yes    NaN      2021
#
# [5 rows x 29 columns]

# %%
data["housePrice"] = housePrice

# %%
data.head()
# Out:
#       city state house      street  ... water sewer  soldYear  housePrice
# 0  Lilburn    GA   249  Rockbridge  ...   Yes   NaN      2021      179300
# 1  LILBURN    GA   NaN         NaN  ...   Yes   NaN      2021      210500
# 2  Lilburn    GA    63   Lancaster  ...   Yes   NaN      2021      251400
# 3  Lilburn    GA   218      Coteau  ...   Yes   NaN      2021      215400
# 4  Lilburn    GA   169       Coeur  ...   Yes   NaN      2021      191800
#
# [5 rows x 30 columns]

# %%
data.drop(columns=["unit", "zip4", "water", "sewer", "house"], inplace=True)

# %%
data.head()
# Out:
#       city state      street  ... fireplace  soldYear  housePrice
# 0  Lilburn    GA  Rockbridge  ...   Masonry      2021      179300
# 1  LILBURN    GA         NaN  ...   Masonry      2021      210500
# 2  Lilburn    GA   Lancaster  ...   Masonry      2021      251400
# 3  Lilburn    GA      Coteau  ...   Masonry      2021      215400
# 4  Lilburn    GA       Coeur  ...   Masonry      2021      191800
#
# [5 rows x 25 columns]

# %%
data["city"].value_counts(dropna=False)
# Out:
# Lawrenceville        75230
# Buford               31856
# Snellville           28706
# Duluth               23616
# Lilburn              19875
# Suwanee              17594
# Norcross             16656
# Dacula               16184
# Loganville           11967
# Peachtree Corners     8626
# Grayson               8053
# Stone Mountain        4309
# Tucker                3180
# Auburn                2186
# Atlanta               2043
# LAWRENCEVILLE         1978
# Hoschton              1742
# LILBURN               1653
# Braselton             1367
# BUFORD                1262
# SNELLVILLE             960
# Bethlehem              892
# DULUTH                 802
# NaN                    772
# SUWANEE                688
# DACULA                 661
# NORCROSS               621
# LOGANVILLE             438
# BRASELTON              266
# GRAYSON                232
# PEACHTREE CORNERS      169
# AUBURN                 114
# TUCKER                  85
# STONE MOUNTAIN          83
# HOSCHTON                61
# BETHLEHEM               55
# ATLANTA                 25
# CONYERS                 12
# Conyers                 10
# Lithonia                 7
# Cumming                  1
# Name: city, dtype: int64

# %%
len(data["city"].unique())
# Out:
# 41

# %%
data["city"] = data["city"].fillna("Others")

# %%
data.city.value_counts(dropna=False)
# Out:
# Lawrenceville        75230
# Buford               31856
# Snellville           28706
# Duluth               23616
# Lilburn              19875
# Suwanee              17594
# Norcross             16656
# Dacula               16184
# Loganville           11967
# Peachtree Corners     8626
# Grayson               8053
# Stone Mountain        4309
# Tucker                3180
# Auburn                2186
# Atlanta               2043
# LAWRENCEVILLE         1978
# Hoschton              1742
# LILBURN               1653
# Braselton             1367
# BUFORD                1262
# SNELLVILLE             960
# Bethlehem              892
# DULUTH                 802
# Others                 772
# SUWANEE                688
# DACULA                 661
# NORCROSS               621
# LOGANVILLE             438
# BRASELTON              266
# GRAYSON                232
# PEACHTREE CORNERS      169
# AUBURN                 114
# TUCKER                  85
# STONE MOUNTAIN          83
# HOSCHTON                61
# BETHLEHEM               55
# ATLANTA                 25
# CONYERS                 12
# Conyers                 10
# Lithonia                 7
# Cumming                  1
# Name: city, dtype: int64

# %%
len(data["city"].unique())
# Out:
# 41

# %%
data["street"].value_counts(dropna=False)
# Out:
# NaN                        10939
# Buford                       941
# Rockbridge                   571
# Oak                          549
# Peachtree Industrial         520
#                            ...
# French                         1
# Castor                         1
# Honeycreek                     1
# Smokecreek                     1
# Sweetgum Martins Chapel        1
# Name: street, Length: 9570, dtype: int64

# %%
data["street"] = data["street"].fillna("Others")

# %%
data["street"].value_counts(dropna=False)
# Out:
# Others                  10939
# Buford                    941
# Rockbridge                571
# Oak                       549
# Peachtree Industrial      520
#                         ...
# Thamesgate                  1
# Clyde Orr                   1
# Castor                      1
# Smokecreek                  1
# Stable                      1
# Name: street, Length: 9570, dtype: int64

# %%
len(data["street"].unique())
# Out:
# 9570

# %%
data["streetSuffix"].value_counts(dropna=False)
# Out:
# Dr      79297
# Ct      39655
# Ln      29705
# Rd      28118
# Way     26112
#         ...
# Pt          7
# Frk         6
# Hvn         5
# Ldg         1
# Gate        1
# Name: streetSuffix, Length: 66, dtype: int64

# %%
data["streetSuffix"].isna().sum()
# Out:
# 12021

# %%
data["streetSuffix"] = data["streetSuffix"].fillna("Others")

# %%
data.isna().sum()
# Out:
# city                      0
# state                     0
# street                    0
# streetSuffix              0
# zip                    1328
# latitude                  0
# longitude                 0
# landUseDescription        0
# zoningDescription     11790
# lotSizeAcres            154
# lotSizeSquareFeet       154
# lotTopography         41201
# condition             17443
# architecturalStyle        0
# yearBuilt             17318
# totalStories          19493
# totalRooms            29595
# bedrooms              29478
# baths                 29713
# heating                   0
# airConditioning       19851
# foundation                0
# fireplace                 0
# soldYear                  0
# housePrice                0
# dtype: int64

# %%
data["zoningDescription"] = data["zoningDescription"].fillna("Others")

# %%
data["landUseDescription"] = data["landUseDescription"].fillna("Others")

# %%
data["lotTopography"] = data["lotTopography"].fillna("Others")

# %%
data.isna().sum()
# Out:
# city                      0
# state                     0
# street                    0
# streetSuffix              0
# zip                    1328
# latitude                  0
# longitude                 0
# landUseDescription        0
# zoningDescription         0
# lotSizeAcres            154
# lotSizeSquareFeet       154
# lotTopography             0
# condition             17443
# architecturalStyle        0
# yearBuilt             17318
# totalStories          19493
# totalRooms            29595
# bedrooms              29478
# baths                 29713
# heating                   0
# airConditioning       19851
# foundation                0
# fireplace                 0
# soldYear                  0
# housePrice                0
# dtype: int64

# %%
cols = data.columns
data.dropna(subset=cols, inplace=True)

# %%
data.describe()
# Out:
#                  zip       latitude  ...  soldYear    housePrice
# count  250341.000000  250341.000000  ...  250341.0  2.503410e+05
# mean    30115.858589      33.625187  ...    2021.0  2.506558e+05
# std       161.102236       3.335820  ...       0.0  1.320538e+05
# min     30011.000000       0.000000  ...    2021.0  0.000000e+00
# 25%     30043.000000      33.889620  ...    2021.0  1.777000e+05
# 50%     30047.000000      33.947601  ...    2021.0  2.233000e+05
# 75%     30093.000000      34.017748  ...    2021.0  2.911000e+05
# max     30620.000000      47.721300  ...    2021.0  1.100430e+07
#
# [8 rows x 12 columns]

# %%
data.shape
# Out:
# (250341, 25)

# %%
import numpy as np
iqr_hp = np.quantile(data['housePrice'],0.75) - np.quantile(data['housePrice'],0.25)
lower_out_hp = np.quantile(data['housePrice'],0.25) - 1.5*iqr_hp
higher_out_hp = np.quantile(data['housePrice'],0.75) + 1.5*iqr_hp
data = data.drop(data[data["housePrice"] > higher_out_hp].index) 
data = data.drop(data[data["housePrice"] < lower_out_hp].index)
data.head()
# Out:
#       city state      street  ... fireplace  soldYear  housePrice
# 0  Lilburn    GA  Rockbridge  ...   Masonry      2021      179300
# 1  LILBURN    GA      Others  ...   Masonry      2021      210500
# 2  Lilburn    GA   Lancaster  ...   Masonry      2021      251400
# 3  Lilburn    GA      Coteau  ...   Masonry      2021      215400
# 4  Lilburn    GA       Coeur  ...   Masonry      2021      191800
#
# [5 rows x 25 columns]

# %%
data.describe()
# Out:
#                  zip       latitude  ...  soldYear     housePrice
# count  238650.000000  238650.000000  ...  238650.0  238650.000000
# mean    30113.600771      33.635082  ...    2021.0  231597.252462
# std       159.083020       3.271609  ...       0.0   79762.136506
# min     30011.000000       0.000000  ...    2021.0   10000.000000
# 25%     30043.000000      33.887902  ...    2021.0  175600.000000
# 50%     30046.000000      33.944578  ...    2021.0  218600.000000
# 75%     30092.000000      34.014788  ...    2021.0  278700.000000
# max     30620.000000      47.721300  ...    2021.0  461200.000000
#
# [8 rows x 12 columns]

# %%
data.shape
# Out:
# (238650, 25)

# %%
# iqr_la = np.quantile(data['lotSizeAcres'],0.75) - np.quantile(data['lotSizeAcres'],0.25)
# lower_out_la = np.quantile(data['lotSizeAcres'],0.25) - 1.5*iqr_la
# higher_out_la = np.quantile(data['lotSizeAcres'],0.75) + 1.5*iqr_la
# data = data[data['lotSizeAcres'] < higher_out_la]
# data = data[data['lotSizeAcres'] > lower_out_la] 
# data.describe()

# %%
iqr_lsf = np.quantile(data['lotSizeSquareFeet'],0.75) - np.quantile(data['lotSizeSquareFeet'],0.25)
lower_out_lsf = np.quantile(data['lotSizeSquareFeet'],0.25) - 1.5*iqr_lsf
higher_out_lsf = np.quantile(data['lotSizeSquareFeet'],0.75) + 1.5*iqr_lsf
data = data.drop(data[data["lotSizeSquareFeet"] > higher_out_lsf].index) 
data = data.drop(data[data["lotSizeSquareFeet"] < lower_out_lsf].index)
data.describe()
# Out:
#                  zip       latitude  ...  soldYear     housePrice
# count  223608.000000  223608.000000  ...  223608.0  223608.000000
# mean    30113.003426      33.660744  ...    2021.0  231032.288201
# std       157.807568       3.141287  ...       0.0   79133.113129
# min     30011.000000       0.000000  ...    2021.0   10000.000000
# 25%     30043.000000      33.889452  ...    2021.0  175600.000000
# 50%     30046.000000      33.945349  ...    2021.0  218000.000000
# 75%     30092.000000      34.014530  ...    2021.0  277300.000000
# max     30620.000000      47.721300  ...    2021.0  461200.000000
#
# [8 rows x 12 columns]

# %%
data.head()
# Out:
#       city state      street  ... fireplace  soldYear  housePrice
# 0  Lilburn    GA  Rockbridge  ...   Masonry      2021      179300
# 1  LILBURN    GA      Others  ...   Masonry      2021      210500
# 2  Lilburn    GA   Lancaster  ...   Masonry      2021      251400
# 3  Lilburn    GA      Coteau  ...   Masonry      2021      215400
# 4  Lilburn    GA       Coeur  ...   Masonry      2021      191800
#
# [5 rows x 25 columns]

# %%
iqr_tr = np.quantile(data['totalRooms'],0.75) - np.quantile(data['totalRooms'],0.25)
#lower_out_tr = np.quantile(data['totalRooms'],0.25) - 1.5*iqr_tr
higher_out_tr = np.quantile(data['totalRooms'],0.75) + 1.5*iqr_tr
data = data.drop(data[data["totalRooms"] > higher_out_tr].index) 
#data = data.drop(data[data["lotSizeSquareFeet"] < lower_out_lsf].index)
data.describe()
# Out:
#                  zip       latitude  ...  soldYear     housePrice
# count  217493.000000  217493.000000  ...  217493.0  217493.000000
# mean    30113.840845      33.657025  ...    2021.0  229375.185408
# std       158.334699       3.160088  ...       0.0   78522.269707
# min     30011.000000       0.000000  ...    2021.0   10000.000000
# 25%     30043.000000      33.889089  ...    2021.0  174600.000000
# 50%     30047.000000      33.945220  ...    2021.0  216500.000000
# 75%     30093.000000      34.014253  ...    2021.0  275000.000000
# max     30620.000000      47.721300  ...    2021.0  461200.000000
#
# [8 rows x 12 columns]

# %%
data.head()
# Out:
#       city state      street  ... fireplace  soldYear  housePrice
# 0  Lilburn    GA  Rockbridge  ...   Masonry      2021      179300
# 1  LILBURN    GA      Others  ...   Masonry      2021      210500
# 2  Lilburn    GA   Lancaster  ...   Masonry      2021      251400
# 3  Lilburn    GA      Coteau  ...   Masonry      2021      215400
# 4  Lilburn    GA       Coeur  ...   Masonry      2021      191800
#
# [5 rows x 25 columns]

# %%
def label_encode(data, column):
  data_copy = data.copy()
  data_copy[column] = data_copy[column].str.lower()
  le = LabelEncoder()
  le.fit(data_copy[column])
  data_copy[column] = le.fit_transform(data_copy[column])
  
  noClasses = le.classes_
  encodings = list(range(len(noClasses)))
  encoding_map = dict(zip(noClasses, encodings))

  return data_copy, encoding_map

# %%
categorical_cols = ["city", "street", "streetSuffix", "landUseDescription", "zoningDescription", "lotTopography", "architecturalStyle", "condition", "heating", "airConditioning",	"foundation", "fireplace"]
numerical_cols = ["zip", "latitude", "longitude", "lotSizeAcres",	"lotSizeSquareFeet",	"yearBuilt",	"totalStories",	"totalRooms",	"bedrooms",	"baths", "soldYear"]

# %%
data.head()
# Out:
#       city state      street  ... fireplace  soldYear  housePrice
# 0  Lilburn    GA  Rockbridge  ...   Masonry      2021      179300
# 1  LILBURN    GA      Others  ...   Masonry      2021      210500
# 2  Lilburn    GA   Lancaster  ...   Masonry      2021      251400
# 3  Lilburn    GA      Coteau  ...   Masonry      2021      215400
# 4  Lilburn    GA       Coeur  ...   Masonry      2021      191800
#
# [5 rows x 25 columns]

# %%
encodings_database = dict()
for column in categorical_cols:
  data, encoding_map = label_encode(data, column)
  encodings_database[column] = encoding_map

# %%
# Encoding State
states = ["AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA","HI","ID","IL","IN",
          "IA","KS","KY","LA","ME","MD","MA","MI","MN","MS","MO","MT","NE","NV",
          "NH","NJ","NM","NY","NC","ND","OH","OK","OR","PA","RI","SC","SD","TN",
          "TX","UT","VT","VA","WA","WV","WI","WY"]

states = list(map(str.lower, states))
states_dict = dict(zip(states, list(range(50))))
print(states_dict)
encodings_database["state"] = states_dict
# Out:
# {'al': 0, 'ak': 1, 'az': 2, 'ar': 3, 'ca': 4, 'co': 5, 'ct': 6, 'de': 7, 'fl': 8, 'ga': 9, 'hi': 10, 'id': 11, 'il': 12, 'in': 13, 'ia': 14, 'ks': 15, 'ky': 16, 'la': 17, 'me': 18, 'md': 19, 'ma': 20, 'mi': 21, 'mn': 22, 'ms': 23, 'mo': 24, 'mt': 25, 'ne': 26, 'nv': 27, 'nh': 28, 'nj': 29, 'nm': 30, 'ny': 31, 'nc': 32, 'nd': 33, 'oh': 34, 'ok': 35, 'or': 36, 'pa': 37, 'ri': 38, 'sc': 39, 'sd': 40, 'tn': 41, 'tx': 42, 'ut': 43, 'vt': 44, 'va': 45, 'wa': 46, 'wv': 47, 'wi': 48, 'wy': 49}

# %%
for state in data.state.unique():
  data["state"][data["state"] == state] = encodings_database["state"][state.lower()]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data["state"]
# Out:
# 0         9
# 1         9
# 2         9
# 3         9
# 4         9
#          ..
# 286903    9
# 286904    9
# 286905    9
# 286906    9
# 286907    9
# Name: state, Length: 217493, dtype: object

# %%
data.head()
# Out:
#    city state  street  ...  fireplace  soldYear  housePrice
# 0    10     9    6422  ...          0      2021      179300
# 1    10     9    5599  ...          0      2021      210500
# 2    10     9    4286  ...          0      2021      251400
# 3    10     9    1864  ...          0      2021      215400
# 4    10     9    1746  ...          0      2021      191800
#
# [5 rows x 25 columns]

# %%
encodings_database.keys()
# Out:
# dict_keys(['city', 'street', 'streetSuffix', 'landUseDescription', 'zoningDescription', 'lotTopography', 'architecturalStyle', 'condition', 'heating', 'airConditioning', 'foundation', 'fireplace', 'state'])

# %%
encodings_database.values()
# Out:
# dict_values([{'atlanta': 0, 'auburn': 1, 'bethlehem': 2, 'braselton': 3, 'buford': 4, 'dacula': 5, 'duluth': 6, 'grayson': 7, 'hoschton': 8, 'lawrenceville': 9, 'lilburn': 10, 'loganville': 11, 'norcross': 12, 'others': 13, 'peachtree corners': 14, 'snellville': 15, 'stone mountain': 16, 'suwanee': 17, 'tucker': 18}, {'1st': 0, '2nd': 1, '3rd': 2, '5th': 3, 'aaron': 4, 'abba': 5, 'abbey': 6, 'abbey brook': 7, 'abbey hill': 8, 'abbey park': 9, 'abbey pointe': 10, 'abbie kilgore': 11, 'abbott': 12, 'abbotts bridge': 13, 'abbotts oak': 14, 'abbotts pointe': 15, 'abby': 16, 'abby grace': 17, 'abercorn': 18, 'aberdeen': 19, 'abernathy': 20, 'aberrone': 21, 'abilene': 22, 'abinger': 23, 'abington': 24, 'abri': 25, 'academic': 26, 'academy': 27, 'accord': 28, 'ace mcmillian': 29, 'acorn': 30, 'acorn oak': 31, 'acuba': 32, 'adah': 33, 'adair': 34, 'adair hill': 35, 'adams': 36, 'adams acre': 37, 'adams brook': 38, 'adams farm': 39, 'adams lake': 40, 'adams landing': 41, 'adams mill': 42, 'adams pointe': 43, 'add': 44, 'addie field': 45, 'addies': 46, 'addison': 47, 'addison walk': 48, 'addison woods': 49, 'adella': 50, 'adger': 51, 'adley': 52, 'admiral ridge': 53, 'admirals': 54, 'adrian': 55, 'agnes': 56, 'agua': 57, 'ahearn': 58, 'ailey': 59, 'ainsley': 60, 'ainsley mill': 61, 'akard': 62, 'alaina': 63, 'alameda creek': 64, 'alamein': 65, 'alamo': 66, 'alamosa': 67, 'alba': 68, 'albemarle': 69, 'albion': 70, 'albion farm': 71, 'albrighton': 72, 'alcazar': 73, 'alcovy': 74, 'alcovy bluff': 75, 'alcovy club': 76, 'alcovy falls': 77, 'alcovy hills': 78, 'alcovy oaks': 79, 'alcovy park': 80, 'alcovy ridge': 81, 'alcovy river': 82, 'alcovy shoals': 83, 'alcovy springs': 84, 'alcovy trace': 85, 'alcovy trails': 86, 'alcovy walk': 87, 'alcovy woods': 88, 'aldenham': 89, 'alder': 90, 'alder tree': 91, 'alderbrooke': 92, 'alderney': 93, 'aldgate': 94, 'alex': 95, 'alexa chase': 96, 'alexander': 97, 'alexander run': 98, 'alexander top': 99, 'alexandra oak': 100, 'alexis': 101, 'alford crest': 102, 'alhambra': 103, 'allatoona': 104, 'allee': 105, 'allen': 106, 'allen lake': 107, 'allen woods': 108, 'allenhurst': 109, 'allens landing': 110, 'allie': 111, 'allison': 112, 'allison woods': 113, 'allsborough': 114, 'allston': 115, 'allwood': 116, 'alma': 117, 'almeda': 118, 'alnwick': 119, 'alp': 120, 'alpha': 121, 'alpine': 122, 'alstead manor': 123, 'alston': 124, 'alta ridge': 125, 'altamont': 126, 'altavista': 127, 'altman': 128, 'alto': 129, 'alton frank': 130, 'alva': 131, 'alvaton': 132, 'alvin': 133, 'alvis': 134, 'alysum': 135, 'amalfi': 136, 'amanda': 137, 'amanda jill': 138, 'amanda leigh': 139, 'amanda louisa': 140, 'amber': 141, 'amber creek': 142, 'amber dawn': 143, 'amber hill': 144, 'amber springs': 145, 'amber valley': 146, 'amber woods': 147, 'amberbrook': 148, 'ambercrest': 149, 'amberden hall': 150, 'amberglade': 151, 'amberglen': 152, 'ambergrove': 153, 'amberleaf': 154, 'amberleigh oak': 155, 'amberly': 156, 'amberly crossing': 157, 'amberly glen': 158, 'amberly hills': 159, 'amberside': 160, 'amberton': 161, 'amberton cls': 162, 'amberwood': 163, 'amberwyck': 164, 'ambria': 165, 'ambridge': 166, 'ambrose creek': 167, 'ambrosia': 168, 'ambur cove': 169, 'ambur lake': 170, 'amelia': 171, 'amelia creek': 172, 'amelia garden': 173, 'amelia grove': 174, 'american': 175, 'american legion': 176, 'amerigo': 177, 'amesbury': 178, 'amhearst mill': 179, 'amhearst oaks': 180, 'amhearst walk': 181, 'amhurst': 182, 'amicalola': 183, 'ammons': 184, 'amour': 185, 'amsterdam': 186, 'amy': 187, 'anamanda cls': 188, 'anchor': 189, 'anchorage': 190, 'anchors': 191, 'ancient oak': 192, 'anconia': 193, 'ancroft': 194, 'anderson': 195, 'anderson livsey': 196, 'andover': 197, 'andrea': 198, 'andrea lee': 199, 'andrew': 200, 'andrew hills': 201, 'andrewood': 202, 'andridge': 203, 'angel oak': 204, 'angela': 205, 'angelica': 206, 'angels': 207, 'angevine': 208, 'angie': 209, 'angora': 210, 'angus lee': 211, 'anise': 212, 'anita bluff': 213, 'anna': 2 ...

# %%
for key, values in encodings_database.items():
  print(f"{key}: {len(values)}")
# Out:
# city: 19
# street: 8786
# streetSuffix: 64
# landUseDescription: 14
# zoningDescription: 79
# lotTopography: 6
# architecturalStyle: 6
# condition: 5
# heating: 5
# airConditioning: 2
# foundation: 2
# fireplace: 2
# state: 50

# %%
assert len(encodings_database.keys()) == len(encodings_database.values())

# %%
data.head()
# Out:
#    city state  street  ...  fireplace  soldYear  housePrice
# 0    10     9    6422  ...          0      2021      179300
# 1    10     9    5599  ...          0      2021      210500
# 2    10     9    4286  ...          0      2021      251400
# 3    10     9    1864  ...          0      2021      215400
# 4    10     9    1746  ...          0      2021      191800
#
# [5 rows x 25 columns]

# %%
data.corr()
# Out:
#                         city    street  ...  soldYear  housePrice
# city                1.000000  0.011946  ...       NaN   -0.051823
# street              0.011946  1.000000  ...       NaN   -0.019149
# streetSuffix       -0.012342 -0.027419  ...       NaN    0.009265
# zip                -0.513132  0.006008  ...       NaN    0.082057
# latitude           -0.008028 -0.042846  ...       NaN    0.007214
# longitude          -0.009679  0.042514  ...       NaN    0.001049
# landUseDescription -0.070253  0.004338  ...       NaN    0.015227
# zoningDescription   0.065046  0.010101  ...       NaN   -0.190900
# lotSizeAcres        0.021847  0.000945  ...       NaN    0.044707
# lotSizeSquareFeet   0.021847  0.000945  ...       NaN    0.044707
# lotTopography      -0.084705 -0.005250  ...       NaN    0.163143
# condition           0.013336 -0.012919  ...       NaN    0.222474
# architecturalStyle  0.023762  0.007600  ...       NaN   -0.388793
# yearBuilt          -0.148785 -0.006072  ...       NaN    0.368595
# totalStories        0.030051  0.012582  ...       NaN    0.371295
# totalRooms         -0.012704 -0.008713  ...       NaN    0.490575
# bedrooms           -0.049777 -0.001850  ...       NaN    0.556179
# baths               0.007939  0.012598  ...       NaN    0.539974
# heating            -0.032099 -0.004907  ...       NaN   -0.029016
# airConditioning     0.028410 -0.002094  ...       NaN    0.029010
# foundation         -0.074417 -0.011466  ...       NaN    0.282591
# fireplace          -0.025102  0.012960  ...       NaN   -0.218452
# soldYear                 NaN       NaN  ...       NaN         NaN
# housePrice         -0.051823 -0.019149  ...       NaN    1.000000
#
# [24 rows x 24 columns]

# %%
data["state"]
# Out:
# 0         9
# 1         9
# 2         9
# 3         9
# 4         9
#          ..
# 286903    9
# 286904    9
# 286905    9
# 286906    9
# 286907    9
# Name: state, Length: 217493, dtype: object

# %%
# NORMALIZATION:
# Now we will be using MinMax Scalar for the Categorical Features
categorical_data = data[categorical_cols]

minMaxScalar = MinMaxScaler()
data[categorical_cols] = minMaxScalar.fit_transform(categorical_data)
data["state"] = data["state"]/49  # For state: Min: 0, Max: 49

# %%
data.head()
# Out:
#        city     state    street  ...  fireplace  soldYear  housePrice
# 0  0.555556  0.183673  0.731019  ...        0.0      2021      179300
# 1  0.555556  0.183673  0.637336  ...        0.0      2021      210500
# 2  0.555556  0.183673  0.487877  ...        0.0      2021      251400
# 3  0.555556  0.183673  0.212180  ...        0.0      2021      215400
# 4  0.555556  0.183673  0.198748  ...        0.0      2021      191800
#
# [5 rows x 25 columns]

# %%
# Converting the dataframe to numeric
data = data.apply(pd.to_numeric, errors="coerce")

# %%
# We use Standard Scalar to scale our numerical data since we have the continuous values without any maximum and minimum values.
numerical_data = data[numerical_cols]

standardScalar = StandardScaler()
data[numerical_cols] = standardScalar.fit_transform(numerical_data)

# %%
if not os.path.exists("/content/Output"):
  os.mkdir("/content/Output")

# %%
with open("/content/Output/encodings_database.json", "w") as f:
  json.dump(encodings_database, f, indent=3)

# %%
data.to_csv("/content/Output/processedData.csv", index=False)

# %%
from joblib import dump

# %%
dump(minMaxScalar, "/content/Output/minMaxScalar.joblib")
dump(standardScalar, "/content/Output/standardScalar.joblib")
# Out:
# ['/content/Output/standardScalar.joblib']

# %%
BASE_DIR = "/content/Output/"
filenames = os.listdir(BASE_DIR)
for filename in filenames:
  file_path = os.path.join(BASE_DIR, filename)
  files.download(file_path)

# %% [markdown]
# # SUMMARY
#
# Since we have only the data for Gwinnett County of GA, the model may be more specific to that county. But we have tried to generalized to other places as well, by introducing the term "Others" for the state, cities, street other than in the Gwinnett County.
#
# We did the following in this notebook:
# * We incorporated "**Architectural Style**", "**Fireplace**", "**Heating**" and "**airConditioning**".
# * We added two featues i.e. **soldYear** and **lastPriceSold** which are the simulated data from the actualMarketValue.
# * Then we encoded all the categorical features using SKLearn **Label Encoder**, and for the **states** we explicitly encoded the values.
# * The label encodings are saved in a **JSON file** which provided the information of the mapping of categorical features with exact index used while data preprocessing.
# * After that, we normalized the categorical data using **MinMaxScalar** since we had the minimum and maximum values after the label encoding part.
# * For the numerical data, we performed the **Standard Scaling Normalization**, by obtaining the mean and standard deviation.
# * The minMaxScalar and standardScalar are dumped into a **pickle file** to use them again while preprocessing the test data.
